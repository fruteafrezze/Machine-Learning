# %% [markdown]
# WEB_1 : How to Work With CSV Files in Python?
#
# https://www.analyticsvidhya.com/blog/2021/08/python-tutorial-working-with-csv-file-for-data-science/

# %%
import csv

# Open the CSV file in read mode
with open('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', 'r') as csvfile:
  # Create a reader object
  csv_reader = csv.reader(csvfile)
  
  # Iterate through the rows in the CSV file
  for row in csv_reader:
    # Access each element in the row
    print(row)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\T'
# <>:4: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_14860\2270953849.py:4: SyntaxWarning: invalid escape sequence '\T'
#   with open('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', 'r') as csvfile:
# ['Row_ID;title;model;battery;price-range;0 - 100;Top Speed;Range*;Efficiency*;Fastcharge*;Germany_price_before_incentives;Netherlands_price_before_incentives;UK_price_after_incentives;Drive_Configuration;Tow_Hitch;Towing_capacity_in_kg;Number_of_seats']
# ['1;Tesla;Model 3;57.5;104;6.1 sec;201 km/h;415 km;139 Wh/km;690 km/h;â‚¬41', '970;â‚¬41', '990;Â£39', '990;Rear Wheel Drive;Towbar possible;1000;5']
# ['2;Tesla;Model Y;57.5;137;6.9 sec;217 km/h;350 km;164 Wh/km;580 km/h;â‚¬45', '970;â‚¬45', '990;Â£44', '990;Rear Wheel Drive;Towbar possible;1600;5']
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', sep=";")

# Access data in the DataFrame using column names or indexing
print(df['model'])
print(df.iloc[0])  # Access first row
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\T'
# <>:4: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_13884\769218957.py:4: SyntaxWarning: invalid escape sequence '\T'
#   df = pd.read_csv('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', sep=";")
# 0                             Model 3
# 1                             Model Y
# 2       Model Y Long Range Dual Motor
# 3       Model 3 Long Range Dual Motor
# 4              Model Y Long Range RWD
#                     ...
# 348          eVito Tourer Long 60 kWh
# 349    eVito Tourer Extra-Long 60 kWh
# 350                        Torres EVX
# 351                          Aceman E
# 352                         Aceman SE
# Name: model, Length: 353, dtype: object
# Row_ID                                                1
# title                                             Tesla
# model                                           Model 3
# ...

# %%
import csv
file = open("D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv")
csvreader = csv.reader(file)
header = next(csvreader)
print(header)
rows = []
for row in csvreader:
    rows.append(row)
print(rows)
file.close()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_13884\1600083854.py:2: SyntaxWarning: invalid escape sequence '\T'
#   file = open("D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv")
# ['Row_ID;title;model;battery;price-range;0 - 100;Top Speed;Range*;Efficiency*;Fastcharge*;Germany_price_before_incentives;Netherlands_price_before_incentives;UK_price_after_incentives;Drive_Configuration;Tow_Hitch;Towing_capacity_in_kg;Number_of_seats']
# ...

# %%
import csv
rows = []
with open("D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    for row in csvreader:
        rows.append(row)
print(header)
print(rows)
# Out:
# ['Row_ID;title;model;battery;price-range;0 - 100;Top Speed;Range*;Efficiency*;Fastcharge*;Germany_price_before_incentives;Netherlands_price_before_incentives;UK_price_after_incentives;Drive_Configuration;Tow_Hitch;Towing_capacity_in_kg;Number_of_seats']
# ...

# %%
with open('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv') as file:
    content = file.readlines()
header = content[:1]
rows = content[1:]
print(header)
print(rows)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_13884\4098013371.py:1: SyntaxWarning: invalid escape sequence '\T'
#   with open('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv') as file:
# ['Row_ID;title;model;battery;price-range;0 - 100;Top Speed;Range*;Efficiency*;Fastcharge*;Germany_price_before_incentives;Netherlands_price_before_incentives;UK_price_after_incentives;Drive_Configuration;Tow_Hitch;Towing_capacity_in_kg;Number_of_seats\n']
# ...

# %%
import pandas as pd

# %%
data= pd.read_csv("D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv",sep=";")
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_13884\896024244.py:1: SyntaxWarning: invalid escape sequence '\T'
#   data= pd.read_csv("D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv",sep=";")
#      Row_ID          title                           model  battery  \
# 0         1          Tesla                         Model 3     57.5
# 1         2          Tesla                         Model Y     57.5
# 2         3          Tesla   Model Y Long Range Dual Motor     75.0
# 3         4          Tesla   Model 3 Long Range Dual Motor     75.0
# 4         5          Tesla          Model Y Long Range RWD     75.0
# ..      ...            ...                             ...      ...
# 348     349  Mercedes-benz        eVito Tourer Long 60 kWh     60.0
# 349     350  Mercedes-benz  eVito Tourer Extra-Long 60 kWh     60.0
# ...

# %%
data.columns
# Out:
# Index(['Row_ID', 'title', 'model', 'battery', 'price-range', '0 - 100',
#        'Top Speed', 'Range*', 'Efficiency*', 'Fastcharge*',
#        'Germany_price_before_incentives',
#        'Netherlands_price_before_incentives', 'UK_price_after_incentives',
#        'Drive_Configuration', 'Tow_Hitch', 'Towing_capacity_in_kg',
#        'Number_of_seats'],
#       dtype='object')

# %%
data.model
# Out:
# 0                             Model 3
# 1                             Model Y
# 2       Model Y Long Range Dual Motor
# 3       Model 3 Long Range Dual Motor
# 4              Model Y Long Range RWD
#                     ...
# 348          eVito Tourer Long 60 kWh
# 349    eVito Tourer Extra-Long 60 kWh
# 350                        Torres EVX
# 351                          Aceman E
# 352                         Aceman SE
# Name: model, Length: 353, dtype: object

# %%
import csv

with open('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
       print(row)
       header = ['Name', 'M1 Score', 'M2 Score']
data = [['Alex', 62, 80], ['Brad', 45, 56], ['Joey', 85, 98]]
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_13884\993275822.py:3: SyntaxWarning: invalid escape sequence '\T'
#   with open('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', 'r') as csvfile:
# {'Row_ID;title;model;battery;price-range;0 - 100;Top Speed;Range*;Efficiency*;Fastcharge*;Germany_price_before_incentives;Netherlands_price_before_incentives;UK_price_after_incentives;Drive_Configuration;Tow_Hitch;Towing_capacity_in_kg;Number_of_seats': '1;Tesla;Model 3;57.5;104;6.1 sec;201 km/h;415 km;139 Wh/km;690 km/h;â‚¬41', None: ['970;â‚¬41', '990;Â£39', '990;Rear Wheel Drive;Towbar possible;1000;5']}
# ...

# %%
header = ['Name', 'M1 Score', 'M2 Score']
data = [['Alex', 62, 80], ['Brad', 45, 56], ['Joey', 85, 98]]

# %%
import csv

filename = 'Students_Data.csv'
with open(filename, 'w', newline="") as file:
    csvwriter = csv.writer(file) # 2. create a csvwriter object
    csvwriter.writerow(header) # 4. write the header
    csvwriter.writerows(data) # 5. write the rest of the data
header = ['Name', 'M1 Score', 'M2 Score']
data = [['Alex', 62, 80], ['Brad', 45, 56], ['Joey', 85, 98]]
filename = 'Student_scores.csv'
with open(filename, 'w') as file:
    for header in header:
        file.write(str(header)+', ')
    file.write('n')
    for row in data:
        for x in row:
            file.write(str(x)+', ')
        file.write('n')

# %%
import pandas as pd

header = ['Name', 'M1 Score', 'M2 Score']
data = [['Alex', 62, 80], ['Brad', 45, 56], ['Joey', 85, 98]]
data = pd.DataFrame(data, columns=header)
data.to_csv('Stu_data.csv', index=False)

# %%
import csv

data = [{'Name': 'Alex', 'M1 Score': 62, 'M2 Score': 80},
        {'Name': 'Brad', 'M1 Score': 45, 'M2 Score': 56},
        {'Name': 'Joey', 'M1 Score': 85, 'M2 Score': 98}]

fieldnames = ['Name', 'M1 Score', 'M2 Score']

with open('Students_Data.csv', 'w', newline='') as csvfile: 
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)

# %% [markdown]
# WEB_2 : 3.1. Statistics in Python
#
# https://scipy-lectures.org/packages/statistics/index.html

# %%
import pandas
data = pandas.read_csv('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', sep=';', na_values=".")
data
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# <>:2: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\FILIPUS FERRY\AppData\Local\Temp\ipykernel_13884\1109024021.py:2: SyntaxWarning: invalid escape sequence '\T'
#   data = pandas.read_csv('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', sep=';', na_values=".")
#      Row_ID          title                           model  battery  \
# 0         1          Tesla                         Model 3     57.5
# 1         2          Tesla                         Model Y     57.5
# 2         3          Tesla   Model Y Long Range Dual Motor     75.0
# 3         4          Tesla   Model 3 Long Range Dual Motor     75.0
# 4         5          Tesla          Model Y Long Range RWD     75.0
# ..      ...            ...                             ...      ...
# 348     349  Mercedes-benz        eVito Tourer Long 60 kWh     60.0
# 349     350  Mercedes-benz  eVito Tourer Extra-Long 60 kWh     60.0
# ...

# %%
import numpy as np
t = np.linspace(-6, 6, 20)
sin_t = np.sin(t)
cos_t = np.cos(t)
pandas.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %%
data.shape    # 40 rows and 8 columns
# Out:
# (353, 17)

# %%
data.columns  # It has columns
# Out:
# Index(['Row_ID', 'title', 'model', 'battery', 'price-range', '0 - 100',
#        'Top Speed', 'Range*', 'Efficiency*', 'Fastcharge*',
#        'Germany_price_before_incentives',
#        'Netherlands_price_before_incentives', 'UK_price_after_incentives',
#        'Drive_Configuration', 'Tow_Hitch', 'Towing_capacity_in_kg',
#        'Number_of_seats'],
#       dtype='object')

# %%
print(data['title'])  # Columns can be addressed by name
# Out:
# 0              Tesla
# 1              Tesla
# 2              Tesla
# 3              Tesla
# 4              Tesla
#            ...
# 348    Mercedes-benz
# 349    Mercedes-benz
# 350              Kgm
# 351             Mini
# 352             Mini
# Name: title, Length: 353, dtype: object

# %%
# Simpler selector
data[data['title'] == 'Tesla']['battery'].mean()
# Out:
# np.float64(77.29166666666667)

# %%
groupby_title = data.groupby('title')
for title, value in groupby_title['batery']:
    print((title, value.mean()))
# Out:
# ('Abarth', np.float64(37.8))
# ('Aiways', np.float64(60.0))
# ('Alfa romeo', np.float64(50.8))
# ('Audi', np.float64(89.55714285714285))
# ('Bmw', np.float64(81.77368421052633))
# ('Byd', np.float64(70.64))
# ('Citroen', np.float64(48.31428571428571))
# ('Cupra', np.float64(71.0))
# ('Dacia', np.float64(25.0))
# ('Ds', np.float64(50.8))
# ('E.go', np.float64(27.0))
# ('Elaris', np.float64(81.0))
# ('Fiat', np.float64(32.371428571428574))
# ('Fisker', np.float64(94.66666666666667))
# ('Ford', np.float64(78.275))
# ('Genesis', np.float64(75.7))
# ('Gwm', np.float64(54.666666666666664))
# ('Honda', np.float64(61.9))
# ('Hongqi', np.float64(92.83333333333333))
# ('Hyundai', np.float64(66.42222222222222))
# ('Jaguar', np.float64(84.7))
# ('Jeep', np.float64(50.8))
# ('Kgm', np.float64(72.0))
# ('Kia', np.float64(73.2))
# ('Lancia', np.float64(48.1))
# ('Lexus', np.float64(64.0))
# ('Lotus', np.float64(104.5))
# ('Lucid', np.float64(98.66666666666667))
# ('Maserati', np.float64(87.0))
# ...

# %%
print(data.dtypes)
data['battery'] = pd.to_numeric(data['battery'], errors='coerce')
groupby_title = data.groupby('title').mean(numeric_only=True)
print(groupby_title)
# Out:
# Row_ID                                   int64
# title                                   object
# model                                   object
# battery                                float64
# price-range                              int64
# 0 - 100                                 object
# Top Speed                               object
# Range*                                  object
# Efficiency*                             object
# Fastcharge*                             object
# Germany_price_before_incentives         object
# Netherlands_price_before_incentives     object
# UK_price_after_incentives               object
# Drive_Configuration                     object
# Tow_Hitch                               object
# Towing_capacity_in_kg                  float64
# Number_of_seats                          int64
# dtype: object
#                    Row_ID     battery  price-range  Towing_capacity_in_kg  \
# title
# ...

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

# Contoh: Membaca dataset dari file CSV
data = pd.read_csv("cars_data_RAW.csv")  # Ganti dengan path file yang benar

# Cek apakah data sudah terbaca
print(data.head())

# Visualisasi scatter matrix
scatter_matrix(data[['Range*', 'Efficiency*', 'Fastcharge*']])
# Out:
#                                                                                                            Row_ID;title;model;battery;price-range;0 - 100;Top Speed;Range*;Efficiency*;Fastcharge*;Germany_price_before_incentives;Netherlands_price_before_incentives;UK_price_after_incentives;Drive_Configuration;Tow_Hitch;Towing_capacity_in_kg;Number_of_seats
# 1;Tesla;Model 3;57.5;104;6.1 sec;201 km/h;415 k... 970;€41 990;£39                                                990;Rear Wheel Drive;Towbar possible;1000;5
# 2;Tesla;Model Y;57.5;137;6.9 sec;217 km/h;350 k... 970;€45 990;£44                                                990;Rear Wheel Drive;Towbar possible;1600;5
# 3;Tesla;Model Y Long Range Dual Motor;75;130;5.... 970;€52 990;£52                                                 990;All Wheel Drive;Towbar possible;1600;5
# 4;Tesla;Model 3 Long Range Dual Motor;75;106;4.... 970;€49 990;£49                                                 990;All Wheel Drive;Towbar possible;1000;5
# ...

# %%
scatter_matrix(data[['range', 'efficiency', 'fastcharge']])  # Sesuaikan dengan yang benar
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 scatter_matrix(data[['range', 'efficiency', 'fastcharge']])  # Sesuaikan dengan yang benar
#
# File c:\Users\FILIPUS FERRY\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\FILIPUS FERRY\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
from pandas.tools import plotting
plotting.scatter_matrix(data[['Range', 'Efficiency', 'Fastcharge']])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandas.tools import plotting
#       2 plotting.scatter_matrix(data[['Range', 'Efficiency', 'Fastcharge']])
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %%
plotting.scatter_matrix(data[['Price-range', '0-100', 'Top Speed']])

# %%
from scipy import stats

# %%
stats.ttest_1samp(data['Price-range'], 0)

# %%
tesla_viq = data[data['title'] == 'Tesla']['Price-range']
bmw_viq = data[data['title'] == 'BMW']['Price-range']
stats.ttest_ind(tesla_viq, bmw_viq)

# %%
stats.ttest_ind(data['0-100'], data['Top Speed'])

# %%
stats.ttest_rel(data['0-100'], data['Top Speed'])

# %%
stats.ttest_1samp(data['0-100'] - data['Top Speed'], 0)

# %%
stats.wilcoxon(data['0-100'], data['Top Speed'])

# %%
import numpy as np
x = np.linspace(-5, 5, 20)
np.random.seed(1)
# normal distributed noise
y = -5 + 3*x + 4 * np.random.normal(size=x.shape)
# Create a data frame containing all the relevant variables
data = pandas.DataFrame({'x': x, 'y': y})

# %%
from statsmodels.formula.api import ols
model = ols("y ~ x", data).fit()

# %%
print(model.summary())

# %%
data = pandas.read_csv('D:\TUGAS KULIAH\SEMESTER 4\Machine Learning\Praktikum\Prak-1\cars_data_RAW.csv', sep=';', na_values=".")

# %%
model = ols("Price-range ~ title + 1", data).fit()
print(model.summary())

# %%
model = ols('Price-range ~ C(title)', data).fit()

# %%
data_fisq = pandas.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pandas.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pandas.concat((data_fisq, data_piq))
print(data_long)  
model = ols("iq ~ type", data_long).fit()
print(model.summary())

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])

# %%
data = pandas.read_csv('examples/iris.csv')
model = ols('sepal_width ~ name + petal_length', data).fit()
print(model.summary())

# %%
print(model.f_test([0, 1, -1, 0]))

# %%
print(data)

# %%
import seaborn
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],kind='reg')

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],kind='reg', hue='SEX')

# %%
from matplotlib import pyplot as plt
plt.rcdefaults()

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

# %%
result = sm.ols(formula='wage ~ education + gender + education * gender',data=data).fit()    
print(result.summary())

# %% [markdown]
# WEB_3 : Pandas DataFrame describe() Method
#
# https://www.geeksforgeeks.org/python-pandas-dataframe-describe-method/

# %%
print("Hello World!")
# Out:
# Hello World!
